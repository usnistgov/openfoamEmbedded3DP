# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("../")
import folderparser as fp
import folderscraper as fs
import interfacemetrics as intm
from interfacePlots import *
from config import cfg

# %%
for topfolder in [os.path.join(cfg.path.server, 'viscositysweep', s) for s in ['newtnewtsweep', 'newtHBsweep', 'HBnewtsweep', 'HBHBsweep']]:
    for folder in fp.caseFolders(topfolder):
        fn = os.path.join(folder, 'images', 'convergence.png')
        if not os.path.exists(fn):
            fig = fs.plotConvergence(folder, [])
            fig.savefig(fn, bbox_inches='tight')
            print(fn)
# Out:
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb21\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb22\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb23\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb24\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb25\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb26\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb27\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb28\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb29\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb30\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb31\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb32\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb33\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb34\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb35\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb36\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb37\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb38\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb39\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb40\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb41\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb42\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb43\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb44\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb45\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb46\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb47\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb475\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb476\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb477\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb478\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb479\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb48\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb480\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb481\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb482\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb483\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb484\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb485\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb486\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb487\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb488\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb489\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb49\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb490\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb491\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb492\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb493\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb494\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb495\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb496\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb497\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb498\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb499\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb50\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb500\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb501\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb502\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb503\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb504\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb505\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb506\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb507\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb508\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb509\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb51\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb510\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb511\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb512\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb513\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb514\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb515\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb516\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb517\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb518\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb519\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb52\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb520\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb521\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb522\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb523\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb524\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb525\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb526\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb527\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb528\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb529\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb53\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb530\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb531\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb532\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb533\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb534\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb535\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb536\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb537\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb538\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb539\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb54\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb540\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb541\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb542\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb543\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb544\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb545\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb546\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb547\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb548\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb549\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb55\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb550\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb56\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb57\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb58\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb59\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb60\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb61\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb62\images\convergence.png
# //cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb63\images\convergence.png
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'simTime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-8a4f67bb08ac> in <module>
#       3         fn = os.path.join(folder, 'images', 'convergence.png')
#       4         if not os.path.exists(fn):
# ----> 5             fig = fs.plotConvergence(folder, [])
#       6             fig.savefig(fn, bbox_inches='tight')
#       7             print(fn)
#
# ~\Documents\GitHub\openfoamEmbedded3DP\pythonscripts\folderscraper.py in plotConvergence(folder, li)
#     824     fig.set_size_inches(3, 9)
#     825     fs = 12
# --> 826     axs[0].plot(li['simTime'], li['ralpha'], 'maroon', label='Alpha')
#     827     axs[0].plot(li['simTime'], li['rprgh'], label='p_rgh')
#     828     axs[0].set_yscale("log")
#
# ~\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'simTime'

# %%
fig = fs.plotConvergence(r'//cfs2e.nist.gov/642/NIST_Projects/Additive Manufacturing and Rheology/OpenFOAM/simulations\viscositysweep\newtnewtsweep\nb21', [])
fig
