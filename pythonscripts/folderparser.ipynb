# %%
# %load_ext autoreload
# %autoreload 2
LOGOPENED = False

# %%
import folderparser as fp
import foldermover as fm
LOGOPENED = fp.openLog('folderparser_PG904830.log', LOGOPENED)
import os
import time
SERVERFOLDER = r'\\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded'
CFOLDER = r'C:\Users\lmf1\Documents\OpenFOAM\HBHByielded'

# %% [markdown]
# # Move folders to OneDrive

# %% [markdown]
# ## move C to server

# %%
SERVERFOLDER
# Out:
# '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded'

# %%
fm.copyCtoServerFolders(SERVERFOLDER, CFOLDER, ['k', 'n', 'tau0'], 1)
# Out:
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
#  ---------- Done copying files to server, moving logs
#  ---------- Done moving logs
# ------ all files copied in k
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1041\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1041\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1041\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1041	1.9	22.63		2.5
#  ---------- Copying files from C to server
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.7
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.7\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.7\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.7\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.8
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.8\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.8\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.8\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.9
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.9\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.9\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\1.9\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.1
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.1\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.1\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.1\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.3
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.3\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.3\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.3\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.4
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.4\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.4\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.4\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.5
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.5\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.5\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\2.5\uniform\functionObjects
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case.vtm.series
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2141
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2141\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2279
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2279\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2417
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2417\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2555
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2555\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2693
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2693\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2831
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2831\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2969
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_2969\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3107
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3107\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3245
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3245\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3383
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3383\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3521
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3521\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3659
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3659\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3797
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3797\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3935
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_3935\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_4073
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\case\VTK\case_4073\boundary
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1034\legend.csv
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_0
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_0\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_1246
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_1246\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_2761
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_2761\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_3671
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_3671\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_4251
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_4251\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_4802
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_4802\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_5411
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_5411\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_6042
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_6042\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_6824
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_6824\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_7434
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_7434\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_8035
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\case\VTK\case_8035\boundary
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1035\legend.csv
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.7
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.7\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.7\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.7\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.8
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.8\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.8\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.8\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.9
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.9\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.9\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\1.9\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.1
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.1\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.1\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.1\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.3
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.3\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.3\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.3\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.4
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.4\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.4\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.4\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.5
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.5\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.5\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\2.5\uniform\functionObjects
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case.vtm.series
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2009
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2009\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2142
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2142\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2275
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2275\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2408
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2408\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2541
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2541\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2674
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2674\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2807
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2807\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2940
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_2940\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3073
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3073\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3206
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3206\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3339
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3339\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3472
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3472\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3605
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3605\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3738
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3738\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3871
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\case\VTK\case_3871\boundary
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1036\legend.csv
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.1
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.1\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.1\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.1\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.2
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.2\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.2\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.2\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.3
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.3\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.3\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.3\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.4
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.4\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.4\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.4\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.5
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.5\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.5\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\2.5\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_0
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_0\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1029
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1029\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1382
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1382\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1663
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1663\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1913
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_1913\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2215
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2215\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2548
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2548\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2948
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_2948\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_3445
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_3445\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_3714
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_3714\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_4022
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_4022\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_4533
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_4533\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_490
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_490\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_5571
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_5571\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_6615
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_6615\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_6874
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_6874\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7199
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7199\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7521
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7521\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7824
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_7824\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_783
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_783\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8200
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8200\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8483
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8483\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8857
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_8857\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9140
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9140\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9538
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9538\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9801
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\case\VTK\case_9801\boundary
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1037\legend.csv
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\1
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\1\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\1\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\1\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_0
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_0\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_2662
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_2662\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_4718
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_4718\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_5271
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_5271\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_5924
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_5924\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_6417
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_6417\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_6872
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_6872\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_7336
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_7336\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_8104
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_8104\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_8756
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_8756\boundary
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_9327
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\case\VTK\case_9327\boundary
# Copied \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1039\legend.csv
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.6
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.6\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.6\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.6\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.7
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.7\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.7\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.7\uniform\functionObjects
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.8
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.8\polyMesh
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.8\uniform
# Created directory \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n\nb1040\case\1.8\uniform\functionObjects
# ...
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.2	33.33		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 04:00:05
# Waiting 1 hour
#
#
#
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in k, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\k\\nb1014\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.2	33.25		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 05:00:22
# Waiting 1 hour
#
#
#
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in k, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\k\\nb1014\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.3	32.94		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 06:00:39
# Waiting 1 hour
#
#
#
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in k, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\k\\nb1014\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.3	32.78		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 07:00:57
# Waiting 1 hour
#
#
#
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in k, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\k\\nb1014\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.4	32.58		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 08:01:15
# Waiting 1 hour
#
#
#
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\k \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\k
# Populating legends
# ###### done: nb1019, nb1020, nb1021, nb1022, nb1023, nb1026, nb1027, nb1028, nb1029, nb1030, nb1031
# ###### not started:
# ###### aborted at 1: nb1014, nb1015
# ###### aborted before 1: nb1016, nb1017, nb1018, nb1024, nb1025
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in k, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\k\\nb1014\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\n
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1032\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1033\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1035\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1038\legend.csv
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\n\nb1039\legend.csv
# ###### done: nb1034, nb1036, nb1037, nb1040, nb1041, nb1042, nb1043, nb1044, nb1045, nb1046, nb1047, nb1048, nb1049
# ###### not started:
# ###### aborted at 1: nb1035, nb1039
# ###### aborted before 1: nb1032, nb1033, nb1038
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
#  ---------- Copying files from C to server
# ----- ERROR in n, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\n\\nb1032\\case\\0\\alpha.ink'
# C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0 \\cfs2e.nist.gov\642\NIST_Projects\Additive Manufacturing and Rheology\OpenFOAM\simulations\yieldingsweep\HBHByielded\tau0
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Populating legends
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\case\VTK\case.vtm.series
# Exported file C:\Users\lmf1\Documents\OpenFOAM\HBHByielded\tau0\nb1053\legend.csv
# ###### done: nb1050, nb1051, nb1052, nb1054, nb1055, nb1056
# ###### not started:
# ###### aborted at 1:
# ###### aborted before 1:
# ###### in progress:
# folder	time	rate (hr/s)	endtime(s)
# nb1053	2.4	32.42		2.5
#  ---------- Copying files from C to server
# ----- ERROR in tau0, [Errno 22] Invalid argument: '\\\\cfs2e.nist.gov\\642\\NIST_Projects\\Additive Manufacturing and Rheology\\OpenFOAM\\simulations\\yieldingsweep\\HBHByielded\\tau0\\nb1050\\case\\0\\alpha.ink'
# ------ Current Time = 02/26/21, 09:01:32
# Waiting 1 hour
