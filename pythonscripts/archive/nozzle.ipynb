# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
bathwidth = 10;
bathheight = bathwidth;
nozbot = bathheight/2;
nozwidth = 2;
pts = np.array([[0,0], [bathwidth, 0], [bathwidth, bathheight], [0, bathheight],
       [bathwidth/2-nozwidth/2,bathheight], [bathwidth/2-nozwidth/2,nozbot],
       [bathwidth/2+nozwidth/2, nozbot], [bathwidth/2+nozwidth/2, bathheight], 
        [0, nozbot], [bathwidth, nozbot]])

fig2 = plt.scatter(pts[:,0], pts[:,1])

# %%
pts2 = np.transpose(np.vstack((np.transpose(pts), np.zeros((1,len(pts))))))
pts3 = np.transpose(np.vstack((np.transpose(pts), np.ones((1,len(pts))))))
pts4 = np.vstack((pts2, pts3))

# %%
fig = plt.figure(figsize=[8,8])
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim3d(0, bathwidth)
ax.set_ylim3d(0, bathwidth)
ax.set_zlim3d(0, bathwidth)
ax.scatter(pts4[:,0], pts4[:,1], pts4[:,2], s=20, c='red')
for i in range(len(pts4)):
    ax.text(pts4[i,0], pts4[i,1], pts4[i,2], i, color='blue')
