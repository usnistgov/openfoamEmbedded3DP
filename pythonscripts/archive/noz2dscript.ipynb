# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ncreate as nc
import numpy as np

# %%
bathwidth = 5
nozzlemeshsize = 0.005
printspeed = 10
gradingx = 4
gradingy = 8
geo = nc.NozVars(bathwidth, nozzlemeshsize, printspeed, gradingx, gradingy)
out = nc.createNozzleBlockFile(geo)
starttime = 0
endtime = 5
dt = 0.01
writedt = 0.1
out.controlDict = nc.compileCDVars(starttime, endtime, dt, writedt)
# Out:
# ncreate imported

# %%
print(out.blockMeshDict)
# Out:
# /*--------------------------------*- C++ -*----------------------------------*
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v1912                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# *---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      blockMeshDict;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //;
#
#
# scale 0.001;
#
# vertices
# (
# 	(0.0 0.0 0.0 )
# 	(2.0465 0.0 0.0 )
# 	(2.1985 0.0 0.0 )
# 	(2.8015 0.0 0.0 )
# 	(2.9535 0.0 0.0 )
# 	(5.0 0.0 0.0 )
# 	(0.0 2.5 0.0 )
# 	(2.0465 2.5 0.0 )
# ...
